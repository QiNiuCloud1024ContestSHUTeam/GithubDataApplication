# %%
import time
from urllib.request import urlopen
from urllib.request import Request
import json
import requests
import os
import re
from urllib.error import HTTPError, URLError

# %%
# 请求头
TopicHeaders = {
    'Cookie': '_octo=GH1.1.547050398.1730121222; _device_id=73a715dea9188e9052280e9ba8f00a3d; saved_user_sessions=124904356%3AFGDwEe-yLWPAB9iCFsxyTgm-Ij8frauGVZNDils0DyQ_FDi4; user_session=FGDwEe-yLWPAB9iCFsxyTgm-Ij8frauGVZNDils0DyQ_FDi4; __Host-user_session_same_site=FGDwEe-yLWPAB9iCFsxyTgm-Ij8frauGVZNDils0DyQ_FDi4; logged_in=yes; dotcom_user=yizhilsy; color_mode=%7B%22color_mode%22%3A%22auto%22%2C%22light_theme%22%3A%7B%22name%22%3A%22light%22%2C%22color_mode%22%3A%22light%22%7D%2C%22dark_theme%22%3A%7B%22name%22%3A%22dark%22%2C%22color_mode%22%3A%22dark%22%7D%7D; preferred_color_mode=light; tz=Asia%2FShanghai; _gh_sess=wgcGGu1teQcioqHPiWBCx0tVV%2BgI4OSl5S1WSmwI4%2BLlrg7DS2GFaw1Z%2BTJRYq4SKGHp%2Fm4b9ZkIfhQqgACyapyAa8XZtdkOIGF%2Fkk%2BTwIj9ibdWec5%2B8oofaPsQipgRe7Jmfv3LPdqazTY%2BxAj8IujwSpfd%2BSaJqI3QPiZucUbs%2FYPRwWQfcz7qWrb0%2Ftzbd0eeLfAQg75s1uxusz67iprHm%2Fl0rFU6ZOrzMB1Gl4uVPDXP%2FkOwpiCLFvgWUaKEgTAEy2C4T%2BMTFL285JZ1cDY1rM0TPhOkU89zIezfnw6YflOnC%2FE%2FhgRne3QOWKI1mAvd%2BleJNC3EE0nVhVZwC5I%2FQw0%2BuJGikotXbvSc0MWRrHsaD1Nen3gR6WAchiW6--2m9XRat%2B2oaDceNY--FmGSxVluLBuvzl1Y7CQe5A%3D%3D',
    'Sec-Ch-Ua-Platform': '"Windows"',
    'X-Requested-With': 'XMLHttpRequest',
    'Accept-Language': 'zh-CN,zh;q=0.9',
    'Accept': 'text/html',
    'Sec-Ch-Ua': '"Not?A_Brand";v="99", "Chromium";v="130"',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.6723.59 Safari/537.36',
    'Sec-Ch-Ua-Mobile': '?0',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Dest': 'empty',
    'Referer': 'https://github.com/topics',
    'Accept-Encoding': 'gzip, deflate, br'
}
def get_Topics(page):
    # URL
    url = 'https://github.com/topics?page={page}'.format(page = page)
    response = requests.get(url, headers=TopicHeaders)
    # 检查请求是否成功
    if response.status_code == 200:
        return response.text    # 返回 HTML 内容
    else:
        print(f"请求失败，状态码：{response.status_code}")
        return None

RepoHeaders = {'User-Agent': 'Mozilla/5.0',
               'Authorization': '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',
               'Content-Type': 'application/json',
               'Accept': 'application/vnd.github.text-match+json'}

def fetch_page(url):
    while True:
        try:
            req = Request(url, headers=RepoHeaders)
            response = urlopen(req)
            if response.getcode() == 200:
                return json.loads(response.read().decode())
            else:
                print(f"请求失败，HTTP状态码: {response.getcode()}，重试...")
        except (HTTPError, URLError) as e:
            print(f"请求错误: {e}, 正在重试...")
        time.sleep(5)  # 等待一段时间再重试

# 获取topic搜索条件下的所有仓库
def get_ReposByTopic(topic):
    targetPath = './Repos/{}/AllReposUnder{}.json'.format(topic, topic)
    # 检测文件是否存在
    if os.path.exists(targetPath):
        print(f"{topic}的仓库信息已存在于:{targetPath}")
        return
    
    repoItems_list = []
    # 请求topic下的第一页数据
    page = 1
    per_page = 100
    url = 'https://api.github.com/search/repositories?q=topic:{topic}&page={page}&per_page={per_page}&sort=stars&order=desc'.format(topic=topic, page = page,per_page = per_page)
    result = fetch_page(url)
    # 计算总条数以及总共需要请求的页数
    total_count = result['total_count']
    total_page = total_count // per_page + 1
    # 出于效率和时间的考量，限定total_page最大为100
    total_page = min(100, total_page)
    # 上一页的最后一个仓库的star数
    starThreshold = result['items'][len(result['items']) - 1]['stargazers_count']
    for item in result['items']:
        repoItems_list.append(item)
    print(f"topic: {topic}下的第{page}页数据已请求，共{total_page}页")
    time.sleep(5)
    
    for page in range(2, total_page + 1):
        # 后续页数的请求
        urlFolllow = 'https://api.github.com/search/repositories?q=topic:{topic}%20stars:<={starThreshold}&page={page}&per_page={per_page}&sort=stars&order=desc'.format(topic = topic, starThreshold = starThreshold, page = 1,per_page = per_page)
        result = fetch_page(urlFolllow)
        for item in result['items']:
            repoItems_list.append(item)
        print(f"topic: {topic}下的第{page}页数据已请求，共{total_page}页")
        starThreshold = result['items'][len(result['items']) - 1]['stargazers_count']
        time.sleep(5)
        
    # 封装成字典
    datadictionary = {'total_count': total_count, 'items': repoItems_list}
    
    # 将repoItems_list中的信息保存到本地json文件中
    with open(targetPath, 'w', encoding='utf-8') as json_file:
        json.dump(datadictionary, json_file, ensure_ascii=False, indent=4)

# %%
# 获取所有官方topic的html文件（6页page）
for page in range(1, 7):
    topic_html = get_Topics(page)
    if os.path.exists("./topicPages/topics_page_{}.html".format(page)):
        print("./topicPages/topics_page_{}.html文件已存在".format(page))
        continue
    else:
        with open("./topicPages/topics_page_{}.html".format(page), "w", encoding="utf-8") as f:
            f.write(topic_html)

# %%
# 读取爬取的html文件分割出官方topic字符串存入文件中
# 设置文件目录
directory = "./topicPages/"
# 正则表达式模式
pattern = r'<a href="/topics/(.*?)"'
topics_list = []
for page in range(1, 7):
    filename = f"topics_page_{page}.html"
    filepath = os.path.join(directory, filename)
    with open(filepath, "r", encoding="utf-8") as f:
        content = f.read()
        # 查找所有匹配的字符串
        matches = re.findall(pattern, content)
        if matches:
            matchesLen = len(matches)
            for index in range(0, matchesLen, 2):
                topics_list.append(matches[index])

# 检查文件是否存在
if os.path.exists("./topicPages/govTopics.txt"):
    print(f"存储所有官方topic的txt文件已存在于:./topicPages/govTopics.txt")
else:
    # 写入文件
    with open("./topicPages/govTopics.txt", "a", encoding="utf-8") as f:
        count = 1
        for topic in topics_list:
            f.write(str(count) + ":" + topic + "\n")
            count = count + 1
    print(count-1)
# Out:
# 166

# %%
# 爬取官方topic下的所有仓库 日期2024/10/31
govTopicFile = "./topicPages/govTopics.txt"
repo_folder = "./Repos"
with open(govTopicFile, "r", encoding="utf-8") as f:
    lines = f.readlines()
    for line in lines:
        govTopic = line.split(":")[1].strip()
        folder_name = f"{govTopic}"
        folder_path = os.path.join(repo_folder, folder_name)
        os.makedirs(folder_path,exist_ok=True)
        print(f"新文件夹 `{folder_path}` 已创建")
        get_ReposByTopic(govTopic)
        print(f"{govTopic}的仓库信息已保存至: {folder_path}")
# Out:
# 新文件夹 `./Repos\3d` 已创建
# 3d的仓库信息已存在于:./Repos/3d/AllReposUnder3d.json
# 3d的仓库信息已保存至: ./Repos\3d
# 新文件夹 `./Repos\ajax` 已创建
# ajax的仓库信息已存在于:./Repos/ajax/AllReposUnderajax.json
# ajax的仓库信息已保存至: ./Repos\ajax
# 新文件夹 `./Repos\algorithm` 已创建
# algorithm的仓库信息已存在于:./Repos/algorithm/AllReposUnderalgorithm.json
# algorithm的仓库信息已保存至: ./Repos\algorithm
# 新文件夹 `./Repos\amphp` 已创建
# amphp的仓库信息已存在于:./Repos/amphp/AllReposUnderamphp.json
# amphp的仓库信息已保存至: ./Repos\amphp
# 新文件夹 `./Repos\android` 已创建
# android的仓库信息已存在于:./Repos/android/AllReposUnderandroid.json
# android的仓库信息已保存至: ./Repos\android
# 新文件夹 `./Repos\angular` 已创建
# angular的仓库信息已存在于:./Repos/angular/AllReposUnderangular.json
# angular的仓库信息已保存至: ./Repos\angular
# 新文件夹 `./Repos\ansible` 已创建
# ansible的仓库信息已存在于:./Repos/ansible/AllReposUnderansible.json
# ansible的仓库信息已保存至: ./Repos\ansible
# 新文件夹 `./Repos\api` 已创建
# api的仓库信息已存在于:./Repos/api/AllReposUnderapi.json
# api的仓库信息已保存至: ./Repos\api
# 新文件夹 `./Repos\arduino` 已创建
# arduino的仓库信息已存在于:./Repos/arduino/AllReposUnderarduino.json
# arduino的仓库信息已保存至: ./Repos\arduino
# 新文件夹 `./Repos\aspnet` 已创建
# aspnet的仓库信息已存在于:./Repos/aspnet/AllReposUnderaspnet.json
# aspnet的仓库信息已保存至: ./Repos\aspnet
# 新文件夹 `./Repos\awesome` 已创建
# awesome的仓库信息已存在于:./Repos/awesome/AllReposUnderawesome.json
# awesome的仓库信息已保存至: ./Repos\awesome
# 新文件夹 `./Repos\aws` 已创建
# aws的仓库信息已存在于:./Repos/aws/AllReposUnderaws.json
# aws的仓库信息已保存至: ./Repos\aws
# 新文件夹 `./Repos\azure` 已创建
# azure的仓库信息已存在于:./Repos/azure/AllReposUnderazure.json
# azure的仓库信息已保存至: ./Repos\azure
# 新文件夹 `./Repos\babel` 已创建
# babel的仓库信息已存在于:./Repos/babel/AllReposUnderbabel.json
# babel的仓库信息已保存至: ./Repos\babel
# 新文件夹 `./Repos\bash` 已创建
# bash的仓库信息已存在于:./Repos/bash/AllReposUnderbash.json
# bash的仓库信息已保存至: ./Repos\bash
# 新文件夹 `./Repos\bitcoin` 已创建
# bitcoin的仓库信息已存在于:./Repos/bitcoin/AllReposUnderbitcoin.json
# bitcoin的仓库信息已保存至: ./Repos\bitcoin
# 新文件夹 `./Repos\bootstrap` 已创建
# bootstrap的仓库信息已存在于:./Repos/bootstrap/AllReposUnderbootstrap.json
# bootstrap的仓库信息已保存至: ./Repos\bootstrap
# 新文件夹 `./Repos\bot` 已创建
# bot的仓库信息已存在于:./Repos/bot/AllReposUnderbot.json
# bot的仓库信息已保存至: ./Repos\bot
# 新文件夹 `./Repos\c` 已创建
# c的仓库信息已存在于:./Repos/c/AllReposUnderc.json
# c的仓库信息已保存至: ./Repos\c
# 新文件夹 `./Repos\chrome` 已创建
# chrome的仓库信息已存在于:./Repos/chrome/AllReposUnderchrome.json
# chrome的仓库信息已保存至: ./Repos\chrome
# 新文件夹 `./Repos\chrome-extension` 已创建
# chrome-extension的仓库信息已存在于:./Repos/chrome-extension/AllReposUnderchrome-extension.json
# chrome-extension的仓库信息已保存至: ./Repos\chrome-extension
# 新文件夹 `./Repos\cli` 已创建
# cli的仓库信息已存在于:./Repos/cli/AllReposUndercli.json
# cli的仓库信息已保存至: ./Repos\cli
# 新文件夹 `./Repos\clojure` 已创建
# clojure的仓库信息已存在于:./Repos/clojure/AllReposUnderclojure.json
# clojure的仓库信息已保存至: ./Repos\clojure
# 新文件夹 `./Repos\code-quality` 已创建
# code-quality的仓库信息已存在于:./Repos/code-quality/AllReposUndercode-quality.json
# code-quality的仓库信息已保存至: ./Repos\code-quality
# 新文件夹 `./Repos\code-review` 已创建
# code-review的仓库信息已存在于:./Repos/code-review/AllReposUndercode-review.json
# code-review的仓库信息已保存至: ./Repos\code-review
# 新文件夹 `./Repos\compiler` 已创建
# compiler的仓库信息已存在于:./Repos/compiler/AllReposUndercompiler.json
# compiler的仓库信息已保存至: ./Repos\compiler
# 新文件夹 `./Repos\continuous-integration` 已创建
# continuous-integration的仓库信息已存在于:./Repos/continuous-integration/AllReposUndercontinuous-integration.json
# continuous-integration的仓库信息已保存至: ./Repos\continuous-integration
# 新文件夹 `./Repos\cpp` 已创建
# cpp的仓库信息已存在于:./Repos/cpp/AllReposUndercpp.json
# cpp的仓库信息已保存至: ./Repos\cpp
# 新文件夹 `./Repos\cryptocurrency` 已创建
# cryptocurrency的仓库信息已存在于:./Repos/cryptocurrency/AllReposUndercryptocurrency.json
# cryptocurrency的仓库信息已保存至: ./Repos\cryptocurrency
# 新文件夹 `./Repos\crystal` 已创建
# crystal的仓库信息已存在于:./Repos/crystal/AllReposUndercrystal.json
# crystal的仓库信息已保存至: ./Repos\crystal
# 新文件夹 `./Repos\csharp` 已创建
# csharp的仓库信息已存在于:./Repos/csharp/AllReposUndercsharp.json
# csharp的仓库信息已保存至: ./Repos\csharp
# 新文件夹 `./Repos\css` 已创建
# css的仓库信息已存在于:./Repos/css/AllReposUndercss.json
# css的仓库信息已保存至: ./Repos\css
# 新文件夹 `./Repos\data-structures` 已创建
# data-structures的仓库信息已存在于:./Repos/data-structures/AllReposUnderdata-structures.json
# data-structures的仓库信息已保存至: ./Repos\data-structures
# 新文件夹 `./Repos\data-visualization` 已创建
# data-visualization的仓库信息已存在于:./Repos/data-visualization/AllReposUnderdata-visualization.json
# data-visualization的仓库信息已保存至: ./Repos\data-visualization
# 新文件夹 `./Repos\database` 已创建
# database的仓库信息已存在于:./Repos/database/AllReposUnderdatabase.json
# database的仓库信息已保存至: ./Repos\database
# 新文件夹 `./Repos\deep-learning` 已创建
# deep-learning的仓库信息已存在于:./Repos/deep-learning/AllReposUnderdeep-learning.json
# deep-learning的仓库信息已保存至: ./Repos\deep-learning
# 新文件夹 `./Repos\dependency-management` 已创建
# dependency-management的仓库信息已存在于:./Repos/dependency-management/AllReposUnderdependency-management.json
# dependency-management的仓库信息已保存至: ./Repos\dependency-management
# 新文件夹 `./Repos\deployment` 已创建
# deployment的仓库信息已存在于:./Repos/deployment/AllReposUnderdeployment.json
# deployment的仓库信息已保存至: ./Repos\deployment
# 新文件夹 `./Repos\django` 已创建
# django的仓库信息已存在于:./Repos/django/AllReposUnderdjango.json
# django的仓库信息已保存至: ./Repos\django
# 新文件夹 `./Repos\docker` 已创建
# docker的仓库信息已存在于:./Repos/docker/AllReposUnderdocker.json
# docker的仓库信息已保存至: ./Repos\docker
# 新文件夹 `./Repos\documentation` 已创建
# documentation的仓库信息已存在于:./Repos/documentation/AllReposUnderdocumentation.json
# documentation的仓库信息已保存至: ./Repos\documentation
# 新文件夹 `./Repos\dotnet` 已创建
# dotnet的仓库信息已存在于:./Repos/dotnet/AllReposUnderdotnet.json
# dotnet的仓库信息已保存至: ./Repos\dotnet
# 新文件夹 `./Repos\electron` 已创建
# electron的仓库信息已存在于:./Repos/electron/AllReposUnderelectron.json
# electron的仓库信息已保存至: ./Repos\electron
# 新文件夹 `./Repos\elixir` 已创建
# elixir的仓库信息已存在于:./Repos/elixir/AllReposUnderelixir.json
# elixir的仓库信息已保存至: ./Repos\elixir
# 新文件夹 `./Repos\emacs` 已创建
# emacs的仓库信息已存在于:./Repos/emacs/AllReposUnderemacs.json
# emacs的仓库信息已保存至: ./Repos\emacs
# 新文件夹 `./Repos\ember` 已创建
# ember的仓库信息已存在于:./Repos/ember/AllReposUnderember.json
# ember的仓库信息已保存至: ./Repos\ember
# 新文件夹 `./Repos\emoji` 已创建
# emoji的仓库信息已存在于:./Repos/emoji/AllReposUnderemoji.json
# emoji的仓库信息已保存至: ./Repos\emoji
# 新文件夹 `./Repos\emulator` 已创建
# emulator的仓库信息已存在于:./Repos/emulator/AllReposUnderemulator.json
# emulator的仓库信息已保存至: ./Repos\emulator
# 新文件夹 `./Repos\eslint` 已创建
# eslint的仓库信息已存在于:./Repos/eslint/AllReposUndereslint.json
# eslint的仓库信息已保存至: ./Repos\eslint
# 新文件夹 `./Repos\ethereum` 已创建
# ethereum的仓库信息已存在于:./Repos/ethereum/AllReposUnderethereum.json
# ethereum的仓库信息已保存至: ./Repos\ethereum
# 新文件夹 `./Repos\express` 已创建
# express的仓库信息已存在于:./Repos/express/AllReposUnderexpress.json
# express的仓库信息已保存至: ./Repos\express
# 新文件夹 `./Repos\firebase` 已创建
# firebase的仓库信息已存在于:./Repos/firebase/AllReposUnderfirebase.json
# firebase的仓库信息已保存至: ./Repos\firebase
# 新文件夹 `./Repos\firefox` 已创建
# firefox的仓库信息已存在于:./Repos/firefox/AllReposUnderfirefox.json
# firefox的仓库信息已保存至: ./Repos\firefox
# 新文件夹 `./Repos\flask` 已创建
# flask的仓库信息已存在于:./Repos/flask/AllReposUnderflask.json
# flask的仓库信息已保存至: ./Repos\flask
# 新文件夹 `./Repos\font` 已创建
# font的仓库信息已存在于:./Repos/font/AllReposUnderfont.json
# font的仓库信息已保存至: ./Repos\font
# 新文件夹 `./Repos\framework` 已创建
# framework的仓库信息已存在于:./Repos/framework/AllReposUnderframework.json
# framework的仓库信息已保存至: ./Repos\framework
# 新文件夹 `./Repos\frontend` 已创建
# frontend的仓库信息已存在于:./Repos/frontend/AllReposUnderfrontend.json
# frontend的仓库信息已保存至: ./Repos\frontend
# 新文件夹 `./Repos\game-engine` 已创建
# game-engine的仓库信息已存在于:./Repos/game-engine/AllReposUndergame-engine.json
# game-engine的仓库信息已保存至: ./Repos\game-engine
# 新文件夹 `./Repos\git` 已创建
# git的仓库信息已存在于:./Repos/git/AllReposUndergit.json
# git的仓库信息已保存至: ./Repos\git
# 新文件夹 `./Repos\github-api` 已创建
# github-api的仓库信息已存在于:./Repos/github-api/AllReposUndergithub-api.json
# github-api的仓库信息已保存至: ./Repos\github-api
# 新文件夹 `./Repos\go` 已创建
# go的仓库信息已存在于:./Repos/go/AllReposUndergo.json
# go的仓库信息已保存至: ./Repos\go
# 新文件夹 `./Repos\google` 已创建
# google的仓库信息已存在于:./Repos/google/AllReposUndergoogle.json
# google的仓库信息已保存至: ./Repos\google
# 新文件夹 `./Repos\gradle` 已创建
# gradle的仓库信息已存在于:./Repos/gradle/AllReposUndergradle.json
# gradle的仓库信息已保存至: ./Repos\gradle
# 新文件夹 `./Repos\graphql` 已创建
# graphql的仓库信息已存在于:./Repos/graphql/AllReposUndergraphql.json
# graphql的仓库信息已保存至: ./Repos\graphql
# 新文件夹 `./Repos\gulp` 已创建
# gulp的仓库信息已存在于:./Repos/gulp/AllReposUndergulp.json
# gulp的仓库信息已保存至: ./Repos\gulp
# 新文件夹 `./Repos\hacktoberfest` 已创建
# hacktoberfest的仓库信息已存在于:./Repos/hacktoberfest/AllReposUnderhacktoberfest.json
# hacktoberfest的仓库信息已保存至: ./Repos\hacktoberfest
# 新文件夹 `./Repos\haskell` 已创建
# haskell的仓库信息已存在于:./Repos/haskell/AllReposUnderhaskell.json
# haskell的仓库信息已保存至: ./Repos\haskell
# 新文件夹 `./Repos\homebrew` 已创建
# homebrew的仓库信息已存在于:./Repos/homebrew/AllReposUnderhomebrew.json
# homebrew的仓库信息已保存至: ./Repos\homebrew
# 新文件夹 `./Repos\homebridge` 已创建
# homebridge的仓库信息已存在于:./Repos/homebridge/AllReposUnderhomebridge.json
# homebridge的仓库信息已保存至: ./Repos\homebridge
# 新文件夹 `./Repos\html` 已创建
# html的仓库信息已存在于:./Repos/html/AllReposUnderhtml.json
# html的仓库信息已保存至: ./Repos\html
# 新文件夹 `./Repos\http` 已创建
# http的仓库信息已存在于:./Repos/http/AllReposUnderhttp.json
# http的仓库信息已保存至: ./Repos\http
# 新文件夹 `./Repos\icon-font` 已创建
# icon-font的仓库信息已存在于:./Repos/icon-font/AllReposUndericon-font.json
# icon-font的仓库信息已保存至: ./Repos\icon-font
# 新文件夹 `./Repos\ios` 已创建
# ios的仓库信息已存在于:./Repos/ios/AllReposUnderios.json
# ios的仓库信息已保存至: ./Repos\ios
# 新文件夹 `./Repos\ipfs` 已创建
# ipfs的仓库信息已存在于:./Repos/ipfs/AllReposUnderipfs.json
# ipfs的仓库信息已保存至: ./Repos\ipfs
# 新文件夹 `./Repos\java` 已创建
# java的仓库信息已存在于:./Repos/java/AllReposUnderjava.json
# java的仓库信息已保存至: ./Repos\java
# 新文件夹 `./Repos\javascript` 已创建
# javascript的仓库信息已存在于:./Repos/javascript/AllReposUnderjavascript.json
# javascript的仓库信息已保存至: ./Repos\javascript
# 新文件夹 `./Repos\jekyll` 已创建
# jekyll的仓库信息已存在于:./Repos/jekyll/AllReposUnderjekyll.json
# jekyll的仓库信息已保存至: ./Repos\jekyll
# 新文件夹 `./Repos\jquery` 已创建
# jquery的仓库信息已存在于:./Repos/jquery/AllReposUnderjquery.json
# jquery的仓库信息已保存至: ./Repos\jquery
# 新文件夹 `./Repos\json` 已创建
# json的仓库信息已存在于:./Repos/json/AllReposUnderjson.json
# json的仓库信息已保存至: ./Repos\json
# 新文件夹 `./Repos\julia` 已创建
# julia的仓库信息已存在于:./Repos/julia/AllReposUnderjulia.json
# julia的仓库信息已保存至: ./Repos\julia
# 新文件夹 `./Repos\jupyter-notebook` 已创建
# jupyter-notebook的仓库信息已存在于:./Repos/jupyter-notebook/AllReposUnderjupyter-notebook.json
# jupyter-notebook的仓库信息已保存至: ./Repos\jupyter-notebook
# 新文件夹 `./Repos\koa` 已创建
# koa的仓库信息已存在于:./Repos/koa/AllReposUnderkoa.json
# koa的仓库信息已保存至: ./Repos\koa
# 新文件夹 `./Repos\kotlin` 已创建
# kotlin的仓库信息已存在于:./Repos/kotlin/AllReposUnderkotlin.json
# kotlin的仓库信息已保存至: ./Repos\kotlin
# 新文件夹 `./Repos\kubernetes` 已创建
# kubernetes的仓库信息已存在于:./Repos/kubernetes/AllReposUnderkubernetes.json
# kubernetes的仓库信息已保存至: ./Repos\kubernetes
# 新文件夹 `./Repos\laravel` 已创建
# laravel的仓库信息已存在于:./Repos/laravel/AllReposUnderlaravel.json
# laravel的仓库信息已保存至: ./Repos\laravel
# 新文件夹 `./Repos\latex` 已创建
# latex的仓库信息已存在于:./Repos/latex/AllReposUnderlatex.json
# latex的仓库信息已保存至: ./Repos\latex
# 新文件夹 `./Repos\library` 已创建
# library的仓库信息已存在于:./Repos/library/AllReposUnderlibrary.json
# library的仓库信息已保存至: ./Repos\library
# 新文件夹 `./Repos\linux` 已创建
# linux的仓库信息已存在于:./Repos/linux/AllReposUnderlinux.json
# linux的仓库信息已保存至: ./Repos\linux
# 新文件夹 `./Repos\localization` 已创建
# localization的仓库信息已存在于:./Repos/localization/AllReposUnderlocalization.json
# localization的仓库信息已保存至: ./Repos\localization
# 新文件夹 `./Repos\lua` 已创建
# lua的仓库信息已存在于:./Repos/lua/AllReposUnderlua.json
# lua的仓库信息已保存至: ./Repos\lua
# 新文件夹 `./Repos\machine-learning` 已创建
# machine-learning的仓库信息已存在于:./Repos/machine-learning/AllReposUndermachine-learning.json
# machine-learning的仓库信息已保存至: ./Repos\machine-learning
# 新文件夹 `./Repos\macos` 已创建
# macos的仓库信息已存在于:./Repos/macos/AllReposUndermacos.json
# macos的仓库信息已保存至: ./Repos\macos
# 新文件夹 `./Repos\markdown` 已创建
# markdown的仓库信息已存在于:./Repos/markdown/AllReposUndermarkdown.json
# markdown的仓库信息已保存至: ./Repos\markdown
# 新文件夹 `./Repos\mastodon` 已创建
# mastodon的仓库信息已存在于:./Repos/mastodon/AllReposUndermastodon.json
# mastodon的仓库信息已保存至: ./Repos\mastodon
# 新文件夹 `./Repos\material-design` 已创建
# material-design的仓库信息已存在于:./Repos/material-design/AllReposUndermaterial-design.json
# material-design的仓库信息已保存至: ./Repos\material-design
# 新文件夹 `./Repos\matlab` 已创建
# matlab的仓库信息已存在于:./Repos/matlab/AllReposUndermatlab.json
# matlab的仓库信息已保存至: ./Repos\matlab
# 新文件夹 `./Repos\maven` 已创建
# maven的仓库信息已存在于:./Repos/maven/AllReposUndermaven.json
# maven的仓库信息已保存至: ./Repos\maven
# 新文件夹 `./Repos\minecraft` 已创建
# minecraft的仓库信息已存在于:./Repos/minecraft/AllReposUnderminecraft.json
# minecraft的仓库信息已保存至: ./Repos\minecraft
# 新文件夹 `./Repos\mobile` 已创建
# mobile的仓库信息已存在于:./Repos/mobile/AllReposUndermobile.json
# mobile的仓库信息已保存至: ./Repos\mobile
# 新文件夹 `./Repos\monero` 已创建
# monero的仓库信息已存在于:./Repos/monero/AllReposUndermonero.json
# monero的仓库信息已保存至: ./Repos\monero
# 新文件夹 `./Repos\mongodb` 已创建
# mongodb的仓库信息已存在于:./Repos/mongodb/AllReposUndermongodb.json
# mongodb的仓库信息已保存至: ./Repos\mongodb
# 新文件夹 `./Repos\mongoose` 已创建
# mongoose的仓库信息已存在于:./Repos/mongoose/AllReposUndermongoose.json
# mongoose的仓库信息已保存至: ./Repos\mongoose
# 新文件夹 `./Repos\monitoring` 已创建
# monitoring的仓库信息已存在于:./Repos/monitoring/AllReposUndermonitoring.json
# monitoring的仓库信息已保存至: ./Repos\monitoring
# 新文件夹 `./Repos\mvvmcross` 已创建
# mvvmcross的仓库信息已存在于:./Repos/mvvmcross/AllReposUndermvvmcross.json
# mvvmcross的仓库信息已保存至: ./Repos\mvvmcross
# 新文件夹 `./Repos\mysql` 已创建
# mysql的仓库信息已存在于:./Repos/mysql/AllReposUndermysql.json
# mysql的仓库信息已保存至: ./Repos\mysql
# 新文件夹 `./Repos\nativescript` 已创建
# nativescript的仓库信息已存在于:./Repos/nativescript/AllReposUndernativescript.json
# nativescript的仓库信息已保存至: ./Repos\nativescript
# 新文件夹 `./Repos\nim` 已创建
# nim的仓库信息已存在于:./Repos/nim/AllReposUndernim.json
# nim的仓库信息已保存至: ./Repos\nim
# 新文件夹 `./Repos\nlp` 已创建
# nlp的仓库信息已存在于:./Repos/nlp/AllReposUndernlp.json
# nlp的仓库信息已保存至: ./Repos\nlp
# 新文件夹 `./Repos\nodejs` 已创建
# nodejs的仓库信息已存在于:./Repos/nodejs/AllReposUndernodejs.json
# nodejs的仓库信息已保存至: ./Repos\nodejs
# 新文件夹 `./Repos\nosql` 已创建
# nosql的仓库信息已存在于:./Repos/nosql/AllReposUndernosql.json
# nosql的仓库信息已保存至: ./Repos\nosql
# 新文件夹 `./Repos\npm` 已创建
# npm的仓库信息已存在于:./Repos/npm/AllReposUndernpm.json
# npm的仓库信息已保存至: ./Repos\npm
# 新文件夹 `./Repos\objective-c` 已创建
# objective-c的仓库信息已存在于:./Repos/objective-c/AllReposUnderobjective-c.json
# objective-c的仓库信息已保存至: ./Repos\objective-c
# 新文件夹 `./Repos\opengl` 已创建
# opengl的仓库信息已存在于:./Repos/opengl/AllReposUnderopengl.json
# opengl的仓库信息已保存至: ./Repos\opengl
# 新文件夹 `./Repos\operating-system` 已创建
# operating-system的仓库信息已存在于:./Repos/operating-system/AllReposUnderoperating-system.json
# operating-system的仓库信息已保存至: ./Repos\operating-system
# 新文件夹 `./Repos\p2p` 已创建
# p2p的仓库信息已存在于:./Repos/p2p/AllReposUnderp2p.json
# p2p的仓库信息已保存至: ./Repos\p2p
# 新文件夹 `./Repos\package-manager` 已创建
# package-manager的仓库信息已存在于:./Repos/package-manager/AllReposUnderpackage-manager.json
# package-manager的仓库信息已保存至: ./Repos\package-manager
# 新文件夹 `./Repos\parsing` 已创建
# parsing的仓库信息已存在于:./Repos/parsing/AllReposUnderparsing.json
# parsing的仓库信息已保存至: ./Repos\parsing
# 新文件夹 `./Repos\perl` 已创建
# perl的仓库信息已存在于:./Repos/perl/AllReposUnderperl.json
# perl的仓库信息已保存至: ./Repos\perl
# 新文件夹 `./Repos\phaser` 已创建
# phaser的仓库信息已存在于:./Repos/phaser/AllReposUnderphaser.json
# phaser的仓库信息已保存至: ./Repos\phaser
# 新文件夹 `./Repos\php` 已创建
# php的仓库信息已存在于:./Repos/php/AllReposUnderphp.json
# php的仓库信息已保存至: ./Repos\php
# 新文件夹 `./Repos\pico-8` 已创建
# pico-8的仓库信息已存在于:./Repos/pico-8/AllReposUnderpico-8.json
# pico-8的仓库信息已保存至: ./Repos\pico-8
# 新文件夹 `./Repos\pixel-art` 已创建
# pixel-art的仓库信息已存在于:./Repos/pixel-art/AllReposUnderpixel-art.json
# pixel-art的仓库信息已保存至: ./Repos\pixel-art
# 新文件夹 `./Repos\postgresql` 已创建
# postgresql的仓库信息已存在于:./Repos/postgresql/AllReposUnderpostgresql.json
# postgresql的仓库信息已保存至: ./Repos\postgresql
# 新文件夹 `./Repos\project-management` 已创建
# project-management的仓库信息已存在于:./Repos/project-management/AllReposUnderproject-management.json
# project-management的仓库信息已保存至: ./Repos\project-management
# 新文件夹 `./Repos\publishing` 已创建
# publishing的仓库信息已存在于:./Repos/publishing/AllReposUnderpublishing.json
# publishing的仓库信息已保存至: ./Repos\publishing
# 新文件夹 `./Repos\pwa` 已创建
# pwa的仓库信息已存在于:./Repos/pwa/AllReposUnderpwa.json
# pwa的仓库信息已保存至: ./Repos\pwa
# 新文件夹 `./Repos\python` 已创建
# python的仓库信息已存在于:./Repos/python/AllReposUnderpython.json
# python的仓库信息已保存至: ./Repos\python
# 新文件夹 `./Repos\qt` 已创建
# qt的仓库信息已存在于:./Repos/qt/AllReposUnderqt.json
# qt的仓库信息已保存至: ./Repos\qt
# 新文件夹 `./Repos\r` 已创建
# r的仓库信息已存在于:./Repos/r/AllReposUnderr.json
# r的仓库信息已保存至: ./Repos\r
# 新文件夹 `./Repos\rails` 已创建
# rails的仓库信息已存在于:./Repos/rails/AllReposUnderrails.json
# rails的仓库信息已保存至: ./Repos\rails
# 新文件夹 `./Repos\raspberry-pi` 已创建
# raspberry-pi的仓库信息已存在于:./Repos/raspberry-pi/AllReposUnderraspberry-pi.json
# raspberry-pi的仓库信息已保存至: ./Repos\raspberry-pi
# 新文件夹 `./Repos\ratchet` 已创建
# ratchet的仓库信息已存在于:./Repos/ratchet/AllReposUnderratchet.json
# ratchet的仓库信息已保存至: ./Repos\ratchet
# 新文件夹 `./Repos\react` 已创建
# react的仓库信息已存在于:./Repos/react/AllReposUnderreact.json
# react的仓库信息已保存至: ./Repos\react
# 新文件夹 `./Repos\react-native` 已创建
# react-native的仓库信息已存在于:./Repos/react-native/AllReposUnderreact-native.json
# react-native的仓库信息已保存至: ./Repos\react-native
# 新文件夹 `./Repos\reactiveui` 已创建
# reactiveui的仓库信息已存在于:./Repos/reactiveui/AllReposUnderreactiveui.json
# reactiveui的仓库信息已保存至: ./Repos\reactiveui
# 新文件夹 `./Repos\redux` 已创建
# redux的仓库信息已存在于:./Repos/redux/AllReposUnderredux.json
# redux的仓库信息已保存至: ./Repos\redux
# 新文件夹 `./Repos\rest-api` 已创建
# rest-api的仓库信息已存在于:./Repos/rest-api/AllReposUnderrest-api.json
# rest-api的仓库信息已保存至: ./Repos\rest-api
# 新文件夹 `./Repos\ruby` 已创建
# ruby的仓库信息已存在于:./Repos/ruby/AllReposUnderruby.json
# ruby的仓库信息已保存至: ./Repos\ruby
# 新文件夹 `./Repos\rust` 已创建
# rust的仓库信息已存在于:./Repos/rust/AllReposUnderrust.json
# rust的仓库信息已保存至: ./Repos\rust
# 新文件夹 `./Repos\sass` 已创建
# sass的仓库信息已存在于:./Repos/sass/AllReposUndersass.json
# sass的仓库信息已保存至: ./Repos\sass
# 新文件夹 `./Repos\scala` 已创建
# scala的仓库信息已存在于:./Repos/scala/AllReposUnderscala.json
# scala的仓库信息已保存至: ./Repos\scala
# 新文件夹 `./Repos\scikit-learn` 已创建
# scikit-learn的仓库信息已存在于:./Repos/scikit-learn/AllReposUnderscikit-learn.json
# scikit-learn的仓库信息已保存至: ./Repos\scikit-learn
# 新文件夹 `./Repos\sdn` 已创建
# sdn的仓库信息已存在于:./Repos/sdn/AllReposUndersdn.json
# sdn的仓库信息已保存至: ./Repos\sdn
# 新文件夹 `./Repos\security` 已创建
# security的仓库信息已存在于:./Repos/security/AllReposUndersecurity.json
# security的仓库信息已保存至: ./Repos\security
# 新文件夹 `./Repos\server` 已创建
# server的仓库信息已存在于:./Repos/server/AllReposUnderserver.json
# server的仓库信息已保存至: ./Repos\server
# 新文件夹 `./Repos\serverless` 已创建
# serverless的仓库信息已存在于:./Repos/serverless/AllReposUnderserverless.json
# serverless的仓库信息已保存至: ./Repos\serverless
# 新文件夹 `./Repos\shell` 已创建
# shell的仓库信息已存在于:./Repos/shell/AllReposUndershell.json
# shell的仓库信息已保存至: ./Repos\shell
# 新文件夹 `./Repos\sketch` 已创建
# sketch的仓库信息已存在于:./Repos/sketch/AllReposUndersketch.json
# sketch的仓库信息已保存至: ./Repos\sketch
# 新文件夹 `./Repos\spacevim` 已创建
# spacevim的仓库信息已存在于:./Repos/spacevim/AllReposUnderspacevim.json
# spacevim的仓库信息已保存至: ./Repos\spacevim
# 新文件夹 `./Repos\spring-boot` 已创建
# spring-boot的仓库信息已存在于:./Repos/spring-boot/AllReposUnderspring-boot.json
# spring-boot的仓库信息已保存至: ./Repos\spring-boot
# 新文件夹 `./Repos\sql` 已创建
# sql的仓库信息已存在于:./Repos/sql/AllReposUndersql.json
# sql的仓库信息已保存至: ./Repos\sql
# 新文件夹 `./Repos\storybook` 已创建
# storybook的仓库信息已存在于:./Repos/storybook/AllReposUnderstorybook.json
# storybook的仓库信息已保存至: ./Repos\storybook
# 新文件夹 `./Repos\support` 已创建
# support的仓库信息已存在于:./Repos/support/AllReposUndersupport.json
# support的仓库信息已保存至: ./Repos\support
# 新文件夹 `./Repos\swift` 已创建
# swift的仓库信息已存在于:./Repos/swift/AllReposUnderswift.json
# swift的仓库信息已保存至: ./Repos\swift
# 新文件夹 `./Repos\symfony` 已创建
# symfony的仓库信息已存在于:./Repos/symfony/AllReposUndersymfony.json
# symfony的仓库信息已保存至: ./Repos\symfony
# 新文件夹 `./Repos\telegram` 已创建
# telegram的仓库信息已存在于:./Repos/telegram/AllReposUndertelegram.json
# telegram的仓库信息已保存至: ./Repos\telegram
# 新文件夹 `./Repos\tensorflow` 已创建
# tensorflow的仓库信息已存在于:./Repos/tensorflow/AllReposUndertensorflow.json
# tensorflow的仓库信息已保存至: ./Repos\tensorflow
# 新文件夹 `./Repos\terminal` 已创建
# terminal的仓库信息已存在于:./Repos/terminal/AllReposUnderterminal.json
# terminal的仓库信息已保存至: ./Repos\terminal
# 新文件夹 `./Repos\terraform` 已创建
# terraform的仓库信息已存在于:./Repos/terraform/AllReposUnderterraform.json
# terraform的仓库信息已保存至: ./Repos\terraform
# 新文件夹 `./Repos\testing` 已创建
# topic: testing下的第1页数据已请求，共100页
# topic: testing下的第2页数据已请求，共100页
# topic: testing下的第3页数据已请求，共100页
# topic: testing下的第4页数据已请求，共100页
# topic: testing下的第5页数据已请求，共100页
# topic: testing下的第6页数据已请求，共100页
# topic: testing下的第7页数据已请求，共100页
# topic: testing下的第8页数据已请求，共100页
# topic: testing下的第9页数据已请求，共100页
# topic: testing下的第10页数据已请求，共100页
# topic: testing下的第11页数据已请求，共100页
# topic: testing下的第12页数据已请求，共100页
# topic: testing下的第13页数据已请求，共100页
# topic: testing下的第14页数据已请求，共100页
# topic: testing下的第15页数据已请求，共100页
# topic: testing下的第16页数据已请求，共100页
# topic: testing下的第17页数据已请求，共100页
# topic: testing下的第18页数据已请求，共100页
# topic: testing下的第19页数据已请求，共100页
# topic: testing下的第20页数据已请求，共100页
# topic: testing下的第21页数据已请求，共100页
# topic: testing下的第22页数据已请求，共100页
# topic: testing下的第23页数据已请求，共100页
# topic: testing下的第24页数据已请求，共100页
# topic: testing下的第25页数据已请求，共100页
# topic: testing下的第26页数据已请求，共100页
# topic: testing下的第27页数据已请求，共100页
# topic: testing下的第28页数据已请求，共100页
# topic: testing下的第29页数据已请求，共100页
# topic: testing下的第30页数据已请求，共100页
# topic: testing下的第31页数据已请求，共100页
# topic: testing下的第32页数据已请求，共100页
# topic: testing下的第33页数据已请求，共100页
# topic: testing下的第34页数据已请求，共100页
# topic: testing下的第35页数据已请求，共100页
# topic: testing下的第36页数据已请求，共100页
# topic: testing下的第37页数据已请求，共100页
# topic: testing下的第38页数据已请求，共100页
# topic: testing下的第39页数据已请求，共100页
# topic: testing下的第40页数据已请求，共100页
# topic: testing下的第41页数据已请求，共100页
# topic: testing下的第42页数据已请求，共100页
# topic: testing下的第43页数据已请求，共100页
# topic: testing下的第44页数据已请求，共100页
# topic: testing下的第45页数据已请求，共100页
# topic: testing下的第46页数据已请求，共100页
# topic: testing下的第47页数据已请求，共100页
# topic: testing下的第48页数据已请求，共100页
# topic: testing下的第49页数据已请求，共100页
# topic: testing下的第50页数据已请求，共100页
# topic: testing下的第51页数据已请求，共100页
# topic: testing下的第52页数据已请求，共100页
# topic: testing下的第53页数据已请求，共100页
# topic: testing下的第54页数据已请求，共100页
# topic: testing下的第55页数据已请求，共100页
# topic: testing下的第56页数据已请求，共100页
# topic: testing下的第57页数据已请求，共100页
# topic: testing下的第58页数据已请求，共100页
# topic: testing下的第59页数据已请求，共100页
# topic: testing下的第60页数据已请求，共100页
# topic: testing下的第61页数据已请求，共100页
# topic: testing下的第62页数据已请求，共100页
# topic: testing下的第63页数据已请求，共100页
# topic: testing下的第64页数据已请求，共100页
# topic: testing下的第65页数据已请求，共100页
# topic: testing下的第66页数据已请求，共100页
# topic: testing下的第67页数据已请求，共100页
# topic: testing下的第68页数据已请求，共100页
# topic: testing下的第69页数据已请求，共100页
# topic: testing下的第70页数据已请求，共100页
# topic: testing下的第71页数据已请求，共100页
# topic: testing下的第72页数据已请求，共100页
# topic: testing下的第73页数据已请求，共100页
# topic: testing下的第74页数据已请求，共100页
# topic: testing下的第75页数据已请求，共100页
# topic: testing下的第76页数据已请求，共100页
# topic: testing下的第77页数据已请求，共100页
# topic: testing下的第78页数据已请求，共100页
# topic: testing下的第79页数据已请求，共100页
# topic: testing下的第80页数据已请求，共100页
# topic: testing下的第81页数据已请求，共100页
# topic: testing下的第82页数据已请求，共100页
# topic: testing下的第83页数据已请求，共100页
# topic: testing下的第84页数据已请求，共100页
# topic: testing下的第85页数据已请求，共100页
# topic: testing下的第86页数据已请求，共100页
# topic: testing下的第87页数据已请求，共100页
# topic: testing下的第88页数据已请求，共100页
# topic: testing下的第89页数据已请求，共100页
# topic: testing下的第90页数据已请求，共100页
# topic: testing下的第91页数据已请求，共100页
# topic: testing下的第92页数据已请求，共100页
# topic: testing下的第93页数据已请求，共100页
# topic: testing下的第94页数据已请求，共100页
# topic: testing下的第95页数据已请求，共100页
# topic: testing下的第96页数据已请求，共100页
# topic: testing下的第97页数据已请求，共100页
# topic: testing下的第98页数据已请求，共100页
# topic: testing下的第99页数据已请求，共100页
# topic: testing下的第100页数据已请求，共100页
# testing的仓库信息已保存至: ./Repos\testing
# 新文件夹 `./Repos\twitter` 已创建
# topic: twitter下的第1页数据已请求，共100页
# topic: twitter下的第2页数据已请求，共100页
# topic: twitter下的第3页数据已请求，共100页
# topic: twitter下的第4页数据已请求，共100页
# topic: twitter下的第5页数据已请求，共100页
# topic: twitter下的第6页数据已请求，共100页
# topic: twitter下的第7页数据已请求，共100页
# topic: twitter下的第8页数据已请求，共100页
# topic: twitter下的第9页数据已请求，共100页
# topic: twitter下的第10页数据已请求，共100页
# topic: twitter下的第11页数据已请求，共100页
# topic: twitter下的第12页数据已请求，共100页
# topic: twitter下的第13页数据已请求，共100页
# topic: twitter下的第14页数据已请求，共100页
# topic: twitter下的第15页数据已请求，共100页
# topic: twitter下的第16页数据已请求，共100页
# topic: twitter下的第17页数据已请求，共100页
# topic: twitter下的第18页数据已请求，共100页
# topic: twitter下的第19页数据已请求，共100页
# topic: twitter下的第20页数据已请求，共100页
# topic: twitter下的第21页数据已请求，共100页
# topic: twitter下的第22页数据已请求，共100页
# topic: twitter下的第23页数据已请求，共100页
# topic: twitter下的第24页数据已请求，共100页
# topic: twitter下的第25页数据已请求，共100页
# topic: twitter下的第26页数据已请求，共100页
# topic: twitter下的第27页数据已请求，共100页
# topic: twitter下的第28页数据已请求，共100页
# topic: twitter下的第29页数据已请求，共100页
# topic: twitter下的第30页数据已请求，共100页
# topic: twitter下的第31页数据已请求，共100页
# topic: twitter下的第32页数据已请求，共100页
# topic: twitter下的第33页数据已请求，共100页
# topic: twitter下的第34页数据已请求，共100页
# topic: twitter下的第35页数据已请求，共100页
# topic: twitter下的第36页数据已请求，共100页
# topic: twitter下的第37页数据已请求，共100页
# topic: twitter下的第38页数据已请求，共100页
# topic: twitter下的第39页数据已请求，共100页
# topic: twitter下的第40页数据已请求，共100页
# topic: twitter下的第41页数据已请求，共100页
# topic: twitter下的第42页数据已请求，共100页
# topic: twitter下的第43页数据已请求，共100页
# topic: twitter下的第44页数据已请求，共100页
# topic: twitter下的第45页数据已请求，共100页
# topic: twitter下的第46页数据已请求，共100页
# topic: twitter下的第47页数据已请求，共100页
# topic: twitter下的第48页数据已请求，共100页
# topic: twitter下的第49页数据已请求，共100页
# topic: twitter下的第50页数据已请求，共100页
# topic: twitter下的第51页数据已请求，共100页
# topic: twitter下的第52页数据已请求，共100页
# topic: twitter下的第53页数据已请求，共100页
# topic: twitter下的第54页数据已请求，共100页
# topic: twitter下的第55页数据已请求，共100页
# topic: twitter下的第56页数据已请求，共100页
# topic: twitter下的第57页数据已请求，共100页
# topic: twitter下的第58页数据已请求，共100页
# topic: twitter下的第59页数据已请求，共100页
# topic: twitter下的第60页数据已请求，共100页
# topic: twitter下的第61页数据已请求，共100页
# topic: twitter下的第62页数据已请求，共100页
# topic: twitter下的第63页数据已请求，共100页
# topic: twitter下的第64页数据已请求，共100页
# topic: twitter下的第65页数据已请求，共100页
# topic: twitter下的第66页数据已请求，共100页
# topic: twitter下的第67页数据已请求，共100页
# topic: twitter下的第68页数据已请求，共100页
# topic: twitter下的第69页数据已请求，共100页
# topic: twitter下的第70页数据已请求，共100页
# topic: twitter下的第71页数据已请求，共100页
# topic: twitter下的第72页数据已请求，共100页
# topic: twitter下的第73页数据已请求，共100页
# topic: twitter下的第74页数据已请求，共100页
# topic: twitter下的第75页数据已请求，共100页
# topic: twitter下的第76页数据已请求，共100页
# topic: twitter下的第77页数据已请求，共100页
# topic: twitter下的第78页数据已请求，共100页
# topic: twitter下的第79页数据已请求，共100页
# topic: twitter下的第80页数据已请求，共100页
# topic: twitter下的第81页数据已请求，共100页
# topic: twitter下的第82页数据已请求，共100页
# topic: twitter下的第83页数据已请求，共100页
# topic: twitter下的第84页数据已请求，共100页
# topic: twitter下的第85页数据已请求，共100页
# topic: twitter下的第86页数据已请求，共100页
# topic: twitter下的第87页数据已请求，共100页
# topic: twitter下的第88页数据已请求，共100页
# topic: twitter下的第89页数据已请求，共100页
# topic: twitter下的第90页数据已请求，共100页
# topic: twitter下的第91页数据已请求，共100页
# topic: twitter下的第92页数据已请求，共100页
# topic: twitter下的第93页数据已请求，共100页
# topic: twitter下的第94页数据已请求，共100页
# topic: twitter下的第95页数据已请求，共100页
# topic: twitter下的第96页数据已请求，共100页
# topic: twitter下的第97页数据已请求，共100页
# topic: twitter下的第98页数据已请求，共100页
# topic: twitter下的第99页数据已请求，共100页
# topic: twitter下的第100页数据已请求，共100页
# twitter的仓库信息已保存至: ./Repos\twitter
# 新文件夹 `./Repos\typescript` 已创建
# topic: typescript下的第1页数据已请求，共100页
# topic: typescript下的第2页数据已请求，共100页
# topic: typescript下的第3页数据已请求，共100页
# topic: typescript下的第4页数据已请求，共100页
# topic: typescript下的第5页数据已请求，共100页
# topic: typescript下的第6页数据已请求，共100页
# topic: typescript下的第7页数据已请求，共100页
# topic: typescript下的第8页数据已请求，共100页
# topic: typescript下的第9页数据已请求，共100页
# topic: typescript下的第10页数据已请求，共100页
# topic: typescript下的第11页数据已请求，共100页
# topic: typescript下的第12页数据已请求，共100页
# topic: typescript下的第13页数据已请求，共100页
# topic: typescript下的第14页数据已请求，共100页
# topic: typescript下的第15页数据已请求，共100页
# topic: typescript下的第16页数据已请求，共100页
# topic: typescript下的第17页数据已请求，共100页
# topic: typescript下的第18页数据已请求，共100页
# topic: typescript下的第19页数据已请求，共100页
# topic: typescript下的第20页数据已请求，共100页
# topic: typescript下的第21页数据已请求，共100页
# topic: typescript下的第22页数据已请求，共100页
# topic: typescript下的第23页数据已请求，共100页
# topic: typescript下的第24页数据已请求，共100页
# topic: typescript下的第25页数据已请求，共100页
# topic: typescript下的第26页数据已请求，共100页
# topic: typescript下的第27页数据已请求，共100页
# topic: typescript下的第28页数据已请求，共100页
# topic: typescript下的第29页数据已请求，共100页
# topic: typescript下的第30页数据已请求，共100页
# topic: typescript下的第31页数据已请求，共100页
# topic: typescript下的第32页数据已请求，共100页
# topic: typescript下的第33页数据已请求，共100页
# topic: typescript下的第34页数据已请求，共100页
# topic: typescript下的第35页数据已请求，共100页
# topic: typescript下的第36页数据已请求，共100页
# topic: typescript下的第37页数据已请求，共100页
# topic: typescript下的第38页数据已请求，共100页
# topic: typescript下的第39页数据已请求，共100页
# topic: typescript下的第40页数据已请求，共100页
# topic: typescript下的第41页数据已请求，共100页
# topic: typescript下的第42页数据已请求，共100页
# topic: typescript下的第43页数据已请求，共100页
# topic: typescript下的第44页数据已请求，共100页
# topic: typescript下的第45页数据已请求，共100页
# topic: typescript下的第46页数据已请求，共100页
# topic: typescript下的第47页数据已请求，共100页
# topic: typescript下的第48页数据已请求，共100页
# topic: typescript下的第49页数据已请求，共100页
# topic: typescript下的第50页数据已请求，共100页
# topic: typescript下的第51页数据已请求，共100页
# topic: typescript下的第52页数据已请求，共100页
# topic: typescript下的第53页数据已请求，共100页
# topic: typescript下的第54页数据已请求，共100页
# topic: typescript下的第55页数据已请求，共100页
# topic: typescript下的第56页数据已请求，共100页
# topic: typescript下的第57页数据已请求，共100页
# topic: typescript下的第58页数据已请求，共100页
# topic: typescript下的第59页数据已请求，共100页
# topic: typescript下的第60页数据已请求，共100页
# topic: typescript下的第61页数据已请求，共100页
# topic: typescript下的第62页数据已请求，共100页
# topic: typescript下的第63页数据已请求，共100页
# topic: typescript下的第64页数据已请求，共100页
# topic: typescript下的第65页数据已请求，共100页
# topic: typescript下的第66页数据已请求，共100页
# topic: typescript下的第67页数据已请求，共100页
# topic: typescript下的第68页数据已请求，共100页
# topic: typescript下的第69页数据已请求，共100页
# topic: typescript下的第70页数据已请求，共100页
# topic: typescript下的第71页数据已请求，共100页
# topic: typescript下的第72页数据已请求，共100页
# topic: typescript下的第73页数据已请求，共100页
# topic: typescript下的第74页数据已请求，共100页
# topic: typescript下的第75页数据已请求，共100页
# topic: typescript下的第76页数据已请求，共100页
# topic: typescript下的第77页数据已请求，共100页
# topic: typescript下的第78页数据已请求，共100页
# topic: typescript下的第79页数据已请求，共100页
# topic: typescript下的第80页数据已请求，共100页
# topic: typescript下的第81页数据已请求，共100页
# topic: typescript下的第82页数据已请求，共100页
# topic: typescript下的第83页数据已请求，共100页
# topic: typescript下的第84页数据已请求，共100页
# topic: typescript下的第85页数据已请求，共100页
# topic: typescript下的第86页数据已请求，共100页
# topic: typescript下的第87页数据已请求，共100页
# topic: typescript下的第88页数据已请求，共100页
# topic: typescript下的第89页数据已请求，共100页
# topic: typescript下的第90页数据已请求，共100页
# topic: typescript下的第91页数据已请求，共100页
# topic: typescript下的第92页数据已请求，共100页
# topic: typescript下的第93页数据已请求，共100页
# topic: typescript下的第94页数据已请求，共100页
# topic: typescript下的第95页数据已请求，共100页
# topic: typescript下的第96页数据已请求，共100页
# topic: typescript下的第97页数据已请求，共100页
# topic: typescript下的第98页数据已请求，共100页
# topic: typescript下的第99页数据已请求，共100页
# topic: typescript下的第100页数据已请求，共100页
# typescript的仓库信息已保存至: ./Repos\typescript
# 新文件夹 `./Repos\ubuntu` 已创建
# topic: ubuntu下的第1页数据已请求，共92页
# topic: ubuntu下的第2页数据已请求，共92页
# topic: ubuntu下的第3页数据已请求，共92页
# topic: ubuntu下的第4页数据已请求，共92页
# topic: ubuntu下的第5页数据已请求，共92页
# topic: ubuntu下的第6页数据已请求，共92页
# topic: ubuntu下的第7页数据已请求，共92页
# topic: ubuntu下的第8页数据已请求，共92页
# topic: ubuntu下的第9页数据已请求，共92页
# topic: ubuntu下的第10页数据已请求，共92页
# topic: ubuntu下的第11页数据已请求，共92页
# topic: ubuntu下的第12页数据已请求，共92页
# topic: ubuntu下的第13页数据已请求，共92页
# topic: ubuntu下的第14页数据已请求，共92页
# topic: ubuntu下的第15页数据已请求，共92页
# topic: ubuntu下的第16页数据已请求，共92页
# topic: ubuntu下的第17页数据已请求，共92页
# topic: ubuntu下的第18页数据已请求，共92页
# topic: ubuntu下的第19页数据已请求，共92页
# topic: ubuntu下的第20页数据已请求，共92页
# topic: ubuntu下的第21页数据已请求，共92页
# topic: ubuntu下的第22页数据已请求，共92页
# topic: ubuntu下的第23页数据已请求，共92页
# topic: ubuntu下的第24页数据已请求，共92页
# topic: ubuntu下的第25页数据已请求，共92页
# topic: ubuntu下的第26页数据已请求，共92页
# topic: ubuntu下的第27页数据已请求，共92页
# topic: ubuntu下的第28页数据已请求，共92页
# topic: ubuntu下的第29页数据已请求，共92页
# topic: ubuntu下的第30页数据已请求，共92页
# topic: ubuntu下的第31页数据已请求，共92页
# topic: ubuntu下的第32页数据已请求，共92页
# topic: ubuntu下的第33页数据已请求，共92页
# topic: ubuntu下的第34页数据已请求，共92页
# topic: ubuntu下的第35页数据已请求，共92页
# topic: ubuntu下的第36页数据已请求，共92页
# topic: ubuntu下的第37页数据已请求，共92页
# topic: ubuntu下的第38页数据已请求，共92页
# topic: ubuntu下的第39页数据已请求，共92页
# topic: ubuntu下的第40页数据已请求，共92页
# topic: ubuntu下的第41页数据已请求，共92页
# topic: ubuntu下的第42页数据已请求，共92页
# topic: ubuntu下的第43页数据已请求，共92页
# topic: ubuntu下的第44页数据已请求，共92页
# topic: ubuntu下的第45页数据已请求，共92页
# topic: ubuntu下的第46页数据已请求，共92页
# topic: ubuntu下的第47页数据已请求，共92页
# topic: ubuntu下的第48页数据已请求，共92页
# topic: ubuntu下的第49页数据已请求，共92页
# topic: ubuntu下的第50页数据已请求，共92页
# topic: ubuntu下的第51页数据已请求，共92页
# topic: ubuntu下的第52页数据已请求，共92页
# topic: ubuntu下的第53页数据已请求，共92页
# topic: ubuntu下的第54页数据已请求，共92页
# topic: ubuntu下的第55页数据已请求，共92页
# topic: ubuntu下的第56页数据已请求，共92页
# topic: ubuntu下的第57页数据已请求，共92页
# topic: ubuntu下的第58页数据已请求，共92页
# topic: ubuntu下的第59页数据已请求，共92页
# topic: ubuntu下的第60页数据已请求，共92页
# topic: ubuntu下的第61页数据已请求，共92页
# topic: ubuntu下的第62页数据已请求，共92页
# topic: ubuntu下的第63页数据已请求，共92页
# topic: ubuntu下的第64页数据已请求，共92页
# topic: ubuntu下的第65页数据已请求，共92页
# topic: ubuntu下的第66页数据已请求，共92页
# topic: ubuntu下的第67页数据已请求，共92页
# topic: ubuntu下的第68页数据已请求，共92页
# topic: ubuntu下的第69页数据已请求，共92页
# topic: ubuntu下的第70页数据已请求，共92页
# topic: ubuntu下的第71页数据已请求，共92页
# topic: ubuntu下的第72页数据已请求，共92页
# topic: ubuntu下的第73页数据已请求，共92页
# topic: ubuntu下的第74页数据已请求，共92页
# topic: ubuntu下的第75页数据已请求，共92页
# topic: ubuntu下的第76页数据已请求，共92页
# topic: ubuntu下的第77页数据已请求，共92页
# topic: ubuntu下的第78页数据已请求，共92页
# topic: ubuntu下的第79页数据已请求，共92页
# topic: ubuntu下的第80页数据已请求，共92页
# topic: ubuntu下的第81页数据已请求，共92页
# topic: ubuntu下的第82页数据已请求，共92页
# topic: ubuntu下的第83页数据已请求，共92页
# topic: ubuntu下的第84页数据已请求，共92页
# topic: ubuntu下的第85页数据已请求，共92页
# topic: ubuntu下的第86页数据已请求，共92页
# topic: ubuntu下的第87页数据已请求，共92页
# topic: ubuntu下的第88页数据已请求，共92页
# topic: ubuntu下的第89页数据已请求，共92页
# topic: ubuntu下的第90页数据已请求，共92页
# topic: ubuntu下的第91页数据已请求，共92页
# topic: ubuntu下的第92页数据已请求，共92页
# ubuntu的仓库信息已保存至: ./Repos\ubuntu
# 新文件夹 `./Repos\unity` 已创建
# topic: unity下的第1页数据已请求，共100页
# topic: unity下的第2页数据已请求，共100页
# topic: unity下的第3页数据已请求，共100页
# topic: unity下的第4页数据已请求，共100页
# topic: unity下的第5页数据已请求，共100页
# topic: unity下的第6页数据已请求，共100页
# topic: unity下的第7页数据已请求，共100页
# topic: unity下的第8页数据已请求，共100页
# topic: unity下的第9页数据已请求，共100页
# topic: unity下的第10页数据已请求，共100页
# topic: unity下的第11页数据已请求，共100页
# topic: unity下的第12页数据已请求，共100页
# topic: unity下的第13页数据已请求，共100页
# topic: unity下的第14页数据已请求，共100页
# topic: unity下的第15页数据已请求，共100页
# topic: unity下的第16页数据已请求，共100页
# topic: unity下的第17页数据已请求，共100页
# topic: unity下的第18页数据已请求，共100页
# topic: unity下的第19页数据已请求，共100页
# topic: unity下的第20页数据已请求，共100页
# topic: unity下的第21页数据已请求，共100页
# topic: unity下的第22页数据已请求，共100页
# topic: unity下的第23页数据已请求，共100页
# topic: unity下的第24页数据已请求，共100页
# topic: unity下的第25页数据已请求，共100页
# topic: unity下的第26页数据已请求，共100页
# topic: unity下的第27页数据已请求，共100页
# topic: unity下的第28页数据已请求，共100页
# topic: unity下的第29页数据已请求，共100页
# topic: unity下的第30页数据已请求，共100页
# topic: unity下的第31页数据已请求，共100页
# topic: unity下的第32页数据已请求，共100页
# topic: unity下的第33页数据已请求，共100页
# topic: unity下的第34页数据已请求，共100页
# topic: unity下的第35页数据已请求，共100页
# topic: unity下的第36页数据已请求，共100页
# topic: unity下的第37页数据已请求，共100页
# topic: unity下的第38页数据已请求，共100页
# topic: unity下的第39页数据已请求，共100页
# topic: unity下的第40页数据已请求，共100页
# topic: unity下的第41页数据已请求，共100页
# topic: unity下的第42页数据已请求，共100页
# topic: unity下的第43页数据已请求，共100页
# topic: unity下的第44页数据已请求，共100页
# topic: unity下的第45页数据已请求，共100页
# topic: unity下的第46页数据已请求，共100页
# topic: unity下的第47页数据已请求，共100页
# topic: unity下的第48页数据已请求，共100页
# topic: unity下的第49页数据已请求，共100页
# topic: unity下的第50页数据已请求，共100页
# topic: unity下的第51页数据已请求，共100页
# topic: unity下的第52页数据已请求，共100页
# topic: unity下的第53页数据已请求，共100页
# topic: unity下的第54页数据已请求，共100页
# topic: unity下的第55页数据已请求，共100页
# topic: unity下的第56页数据已请求，共100页
# topic: unity下的第57页数据已请求，共100页
# topic: unity下的第58页数据已请求，共100页
# topic: unity下的第59页数据已请求，共100页
# topic: unity下的第60页数据已请求，共100页
# topic: unity下的第61页数据已请求，共100页
# topic: unity下的第62页数据已请求，共100页
# topic: unity下的第63页数据已请求，共100页
# topic: unity下的第64页数据已请求，共100页
# topic: unity下的第65页数据已请求，共100页
# topic: unity下的第66页数据已请求，共100页
# topic: unity下的第67页数据已请求，共100页
# topic: unity下的第68页数据已请求，共100页
# topic: unity下的第69页数据已请求，共100页
# topic: unity下的第70页数据已请求，共100页
# topic: unity下的第71页数据已请求，共100页
# topic: unity下的第72页数据已请求，共100页
# topic: unity下的第73页数据已请求，共100页
# topic: unity下的第74页数据已请求，共100页
# topic: unity下的第75页数据已请求，共100页
# topic: unity下的第76页数据已请求，共100页
# topic: unity下的第77页数据已请求，共100页
# topic: unity下的第78页数据已请求，共100页
# topic: unity下的第79页数据已请求，共100页
# topic: unity下的第80页数据已请求，共100页
# topic: unity下的第81页数据已请求，共100页
# topic: unity下的第82页数据已请求，共100页
# topic: unity下的第83页数据已请求，共100页
# topic: unity下的第84页数据已请求，共100页
# topic: unity下的第85页数据已请求，共100页
# topic: unity下的第86页数据已请求，共100页
# topic: unity下的第87页数据已请求，共100页
# topic: unity下的第88页数据已请求，共100页
# topic: unity下的第89页数据已请求，共100页
# topic: unity下的第90页数据已请求，共100页
# topic: unity下的第91页数据已请求，共100页
# topic: unity下的第92页数据已请求，共100页
# topic: unity下的第93页数据已请求，共100页
# topic: unity下的第94页数据已请求，共100页
# topic: unity下的第95页数据已请求，共100页
# topic: unity下的第96页数据已请求，共100页
# topic: unity下的第97页数据已请求，共100页
# topic: unity下的第98页数据已请求，共100页
# topic: unity下的第99页数据已请求，共100页
# topic: unity下的第100页数据已请求，共100页
# unity的仓库信息已保存至: ./Repos\unity
# 新文件夹 `./Repos\unreal-engine` 已创建
# topic: unreal-engine下的第1页数据已请求，共19页
# topic: unreal-engine下的第2页数据已请求，共19页
# topic: unreal-engine下的第3页数据已请求，共19页
# topic: unreal-engine下的第4页数据已请求，共19页
# topic: unreal-engine下的第5页数据已请求，共19页
# topic: unreal-engine下的第6页数据已请求，共19页
# topic: unreal-engine下的第7页数据已请求，共19页
# topic: unreal-engine下的第8页数据已请求，共19页
# topic: unreal-engine下的第9页数据已请求，共19页
# topic: unreal-engine下的第10页数据已请求，共19页
# topic: unreal-engine下的第11页数据已请求，共19页
# topic: unreal-engine下的第12页数据已请求，共19页
# topic: unreal-engine下的第13页数据已请求，共19页
# topic: unreal-engine下的第14页数据已请求，共19页
# topic: unreal-engine下的第15页数据已请求，共19页
# topic: unreal-engine下的第16页数据已请求，共19页
# topic: unreal-engine下的第17页数据已请求，共19页
# topic: unreal-engine下的第18页数据已请求，共19页
# topic: unreal-engine下的第19页数据已请求，共19页
# unreal-engine的仓库信息已保存至: ./Repos\unreal-engine
# 新文件夹 `./Repos\vagrant` 已创建
# topic: vagrant下的第1页数据已请求，共49页
# topic: vagrant下的第2页数据已请求，共49页
# topic: vagrant下的第3页数据已请求，共49页
# topic: vagrant下的第4页数据已请求，共49页
# topic: vagrant下的第5页数据已请求，共49页
# topic: vagrant下的第6页数据已请求，共49页
# topic: vagrant下的第7页数据已请求，共49页
# topic: vagrant下的第8页数据已请求，共49页
# topic: vagrant下的第9页数据已请求，共49页
# topic: vagrant下的第10页数据已请求，共49页
# topic: vagrant下的第11页数据已请求，共49页
# topic: vagrant下的第12页数据已请求，共49页
# topic: vagrant下的第13页数据已请求，共49页
# topic: vagrant下的第14页数据已请求，共49页
# topic: vagrant下的第15页数据已请求，共49页
# topic: vagrant下的第16页数据已请求，共49页
# topic: vagrant下的第17页数据已请求，共49页
# topic: vagrant下的第18页数据已请求，共49页
# topic: vagrant下的第19页数据已请求，共49页
# topic: vagrant下的第20页数据已请求，共49页
# topic: vagrant下的第21页数据已请求，共49页
# topic: vagrant下的第22页数据已请求，共49页
# topic: vagrant下的第23页数据已请求，共49页
# topic: vagrant下的第24页数据已请求，共49页
# topic: vagrant下的第25页数据已请求，共49页
# topic: vagrant下的第26页数据已请求，共49页
# topic: vagrant下的第27页数据已请求，共49页
# topic: vagrant下的第28页数据已请求，共49页
# topic: vagrant下的第29页数据已请求，共49页
# topic: vagrant下的第30页数据已请求，共49页
# topic: vagrant下的第31页数据已请求，共49页
# topic: vagrant下的第32页数据已请求，共49页
# topic: vagrant下的第33页数据已请求，共49页
# topic: vagrant下的第34页数据已请求，共49页
# topic: vagrant下的第35页数据已请求，共49页
# topic: vagrant下的第36页数据已请求，共49页
# topic: vagrant下的第37页数据已请求，共49页
# topic: vagrant下的第38页数据已请求，共49页
# topic: vagrant下的第39页数据已请求，共49页
# topic: vagrant下的第40页数据已请求，共49页
# topic: vagrant下的第41页数据已请求，共49页
# topic: vagrant下的第42页数据已请求，共49页
# topic: vagrant下的第43页数据已请求，共49页
# topic: vagrant下的第44页数据已请求，共49页
# topic: vagrant下的第45页数据已请求，共49页
# topic: vagrant下的第46页数据已请求，共49页
# topic: vagrant下的第47页数据已请求，共49页
# topic: vagrant下的第48页数据已请求，共49页
# topic: vagrant下的第49页数据已请求，共49页
# vagrant的仓库信息已保存至: ./Repos\vagrant

# %%
# 110791
with open('./Repos/algorithm/AllReposUnderalgorithm.json', 'r', encoding='UTF-8') as file:
    data = json.load(file)  # 将 JSON 数据解析为 Python 对象
    total_count = 10000
    items = data['items']
    items = items[0:10000]
    # 封装成字典
    datadictionary = {'total_count': total_count, 'items': items}
    with open('./Repos/algorithm/AllReposUnderalgorithm.json', 'w', encoding='utf-8') as json_file:
        json.dump(datadictionary, json_file, ensure_ascii=False, indent=4)
